# %%
import pandas as pd

df = pd.read_csv("../processed_data/weather.csv", usecols=['date', 'high_F', 'low_F', 'avg_F'])
df['date'] = df['date'].apply(lambda x: pd.to_datetime(x))
df
# Out:
#           date     high_F      low_F      avg_F
# 0   2015-01-01  35.767090  21.569020  26.027578
# 1   2015-01-02  36.270210  26.406464  31.185198
# 2   2015-01-03  40.143715  31.481049  36.379843
# 3   2015-01-04  39.103363  16.318654  31.577264
# 4   2015-01-05  16.346833  -0.360818   5.112399
# ..         ...        ...        ...        ...
# 249 2015-12-20  51.048304  -3.628370  29.806846
# 250 2015-12-21  51.031220  16.174184  45.008008
# 251 2015-12-22  36.288612  -1.663740  19.114465
# 252 2015-12-23  61.899665   0.854105  49.829622
# 253 2015-12-24  61.861928  39.265851  53.245253
#
# [254 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

plt.figure()
df.plot(x="date", y="low_F")

# %%
import fetch

df2 = fetch.get_weather(usecols='oid,time,temp_K', datetime='2015-06-24 06:15')
df2
# Out:
#                                 time      temp_K
# oid
# 11360801  2015-06-24 06:15:00.000000  276.620361
# 11360802  2015-06-24 06:15:00.000000  276.551483
# 11360803  2015-06-24 06:15:00.000000  276.555389
# 11360804  2015-06-24 06:15:00.000000  276.619751
# 11360805  2015-06-24 06:15:00.000000  276.713226
# ...                              ...         ...
# 11361676  2015-06-24 06:15:00.000000  272.949921
# 11361677  2015-06-24 06:15:00.000000  274.742798
# 11361678  2015-06-24 06:15:00.000000  276.038208
# 11361679  2015-06-24 06:15:00.000000  276.355499
# 11361680  2015-06-24 06:15:00.000000  276.094635
#
# [880 rows x 2 columns]
